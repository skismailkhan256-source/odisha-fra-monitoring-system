# %%
import pandas as pd
import pdfplumber

# %%
pdf_path = r"C:\Users\ASUS\OneDrive\Desktop\ALL FOLDER ARE HERE\Project\odisha-fra-monitoring-system\data\raw\Mayurbhanj\MayurbhanjFRABeneficiaries.pdf"

print(pdf_path)
# Out:
# C:\Users\ASUS\OneDrive\Desktop\ALL FOLDER ARE HERE\Project\odisha-fra-monitoring-system\data\raw\Mayurbhanj\MayurbhanjFRABeneficiaries.pdf

# %%
with pdfplumber.open(pdf_path) as pdf:
    print("PDF opened successfully")
    print("Total pages:", len(pdf.pages))
# Out:
# PDF opened successfully
# Total pages: 1802

# %%
with pdfplumber.open(pdf_path) as pdf:
    table = pdf.pages[0].extract_table()

print(table)
# Out:
# [['Sl. No.', 'Block', 'Gram Panchayat', 'Village', 'Name of the FRA\nbeneficairy'], ['1', '2', '3', '4', '5'], ['1', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Raghunath Murmu'], ['2', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Khela Murmu'], ['3', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Narendra Murmu'], ['4', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Ananda Tudu'], ['5', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Maha Kisku'], ['6', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Jadu Marndi'], ['7', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Kunu Murmu'], ['8', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Anta Tudu @ Majhi'], ['9', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Laxman Murmu'], ['10', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Bhimcharan Murmu'], ['11', 'Baripada', 'Sankhabhanga', 'Ranibhole', 'Mangal Soren'], ['12', 'Baripada', 'Khadisole', 'Sankhajod', 'Jagannath Soren'], ['13', 'Baripada', 'Khadisole', 'Sankhajod', 'Barsa Hembram'], ['14', 'Baripada', 'Khadisole', 'Sankhajod', 'Bhuta Hembram'], ['15', 'Baripada', 'Khadisole', 'Sankhajod', 'Repo Soren'], ['16', 'Baripada', 'Khadisole', 'Sankhajod', 'Piru Hembram'], ['17', 'Baripada', 'Khadisole', 'Sankhajod', 'Madhusudan Marndi'], ['18', '', '', '-do-', 'Rama Soren'], ['19', 'R.G. Pur', 'Deosole', 'Musamari', 'Rani Murmu'], ['20', '-do-', '-do-', '-do-', 'Lakay Soren'], ['21', '-do-', '-do-', '-do-', 'Bajun Marndi'], ['22', '-do-', '-do-', '-do-', 'Sukul Hembram'], ['23', '-do-', '-do-', '-do-', 'Samray Hembram'], ['24', '-do-', '-do-', '-do-', 'Singray Hansda'], ['25', '-do-', '-do-', 'Ram Ch. Pur', 'Bisu Majhi @ Baskey'], ['26', '-do-', '-do-', '-do-', 'Thumpu Majhi'], ['27', '-do-', 'Nalagaza', 'Jhirani', 'Kuanr Tudu'], ['28', '-do-', '-do-', '-do-', 'Renta Tudu'], ['2299', '--ddoo--', '--ddoo--', '--ddoo--', 'LLaawwaa TTuudduu'], ['30', '-do-', '-do-', 'Sunakania', 'Kapura Tudu'], ['31', '-do-', '-do-', '-do-', 'Sunaram Besra'], ['32', '-do-', '-do-', '-do-', 'Baijhal Baskey'], ['33', '-do-', '-do-', 'Bahagadia', 'Balai Hembram'], ['34', '-do-', '-do-', '-do-', 'Renta Tudu'], ['35', '-do-', '-do-', '-do-', 'Rajendra Tudu'], ['36', '-do-', '-do-', '-do-', 'Bagharay Besra'], ['37', '-do-', '-do-', '-do-', 'Arjun Marndi'], ['38', 'R.G. Pur', 'Nalagaza', 'Mahulia', 'Lalmohan Soren'], ['39', '-do-', '-do-', 'Sabandihi', 'Bhagirathi Tudu'], ['40', 'Barsahi', 'Naupal', 'Astajharan', 'Jasmi Marndi'], ['41', '-do-', '-do-', '-do-', 'Rama Murmu'], ['42', '-do-', '-do-', '-do-', 'Sukura Murmu'], ['43', '-do-', '-do-', '-do-', 'Dasa Murmu'], ['44', '-do-', '-do-', '-do-', 'Jogeswar Marndi'], ['45', '-do-', '-do-', '-do-', 'Chunuram Kisku'], ['46', '-do-', '-do-', '-do-', 'Soren Murmu'], ['47', '-do-', '-do-', '-do-', 'Mansing Murmu'], ['48', '-do-', '-do-', '-do-', 'Baidhar Murmu'], ['49', '-do-', '-do-', '-do-', 'Pitha Marndi'], ['50', '-do-', 'Naupal', 'Astajharan', 'San Srimath Soren'], ['51', '-do-', '-do-', '-do-', 'Bhima Murmu'], ['52', '-do-', '-do-', '-do-', 'Chandu Marndi'], ['53', '-do-', '-do-', '-do-', 'Chaitan Marndi'], ['54', '-do-', '-do-', '-do-', 'Churia Kisku'], ['55', '-do-', '-do-', '-do-', 'Somay Soren'], ['56', '-do-', '-do-', '-do-', 'Sawana Hembram'], ['57', '-do-', '-do-', '-do-', 'Srimath Murmu'], ['58', '-do-', '-do-', '-do-', 'Baleya Marndi'], ['59', '-do-', '-do-', '-do-', 'Banmali Marndi'], ['60', '-do-', '-do-', '-do-', 'Pandu Murmu'], ['61', 'Barsahi', 'Jadunathpur', 'Jadunathpur', 'Baisnab Singh'], ['6622', '--ddoo--', '--ddoo--', '--ddoo--', 'PPuurrnnaa CChhaannddrraa SSiinngghh'], ['63', '-do-', '-do-', '-do-', 'Minati Singh'], ['64', '-do-', '-do-', '-do-', 'Ramchandra Singh']]
